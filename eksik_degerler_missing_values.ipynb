# %%
import seaborn as sns
import pandas as pd
planets = sns.load_dataset("planets")
df = planets.copy()

# %%
#hiç eksik gözlem var mı ?

df.isnull().values.any()
# Out:
# True

# %%
#varmış

# %%
#hangi değişkende kaçar tane var?
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
#bütün eksik değerlere sıfır basma

#df["degisken_ismi"].fillna(0, inplace = True)

# %%
#bütün eksik değerlere ortalama değeri verme

#df["degisken_ismi"].fillna(df.degisken_ismi.mean(), inplace = True)

# %%
#bir degiskenin değil de bütün veri setinin eksik değerlerine sıfır ya da ortalamayı verme

#df.fillna(df.mean(), inplace = True)

# %%
#verinin bozulduğunu düşünürsek
df = planets.copy()
#komutunu tekrar çalıştırabiliriz.
