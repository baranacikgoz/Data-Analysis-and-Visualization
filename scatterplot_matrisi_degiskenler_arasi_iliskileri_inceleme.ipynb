# %%
import seaborn as sns;
iris = sns.load_dataset("iris")
df = iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df);

# %% [markdown]
# Bu grafiğin sunduğu iki bilgi var
# 1.si eksende yer alan grafikler yani dağılımları gösteriyor,
# 2.si eksenlerden yapılacak kesiştirme ile değişkenlerin birbirleriyle arasındaki ilişkiyi sunuyor

# %%
#######

# %% [markdown]
# Scatterplot grafiklerinde eğer grafik noktasalsa yani sol en üstteki gibi yapısal değilse bu ; o iki değişken arasında bir ilişki olmadığını gösterir, aksi de ilişki olduğunu mesela (1,1),(2,2),(3,3),(4,4), grafiklerinin kesişimlerini sağlayan değerler arasında ilişki vardır

# %%
######

# %% [markdown]
# Ve noktasal grafiklerde birbirinden farklı yerlerde kümelenmeler varsa, çeşitli çaprazlamalar yapılarak , bu kümelenmeyi oluşturan alt gruplar hakkında bilgi elde edilebileceği anlamına gelir.

# %%
##

# %%
sns.pairplot(df, hue = "species");

# %% [markdown]
# İlk "sns.pairplot(df);" grafiğine bakılarak işte bu değişken artarken bu da artmış gibi bir yorum yapmanın doğru olmadığını gösteriyor bu grafik bize.
# Olay sadece biri artarken diğeri artmış değil, türler bu durumu etkilemiş kesinlikle.

# %%
sns.pairplot(df, hue = "species", kind = "reg");
